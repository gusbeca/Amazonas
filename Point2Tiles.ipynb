# %%
#PLANET_API_KEY='cfb9acbc5bdb4cb496bcf33d57d28738'
from planet import api
from requests.auth import HTTPBasicAuth
from osgeo import ogr, gdal, osr
import xml.dom.minidom
import http.client

import math


import requests, json, geopandas as gpd
import os
import pandas as pd
import geojson
import numpy as np
from pygeotile.tile import Tile
from pyproj import Proj, transform

from PIL import Image

from pymongo import MongoClient 
import datetime
clientMongo = MongoClient('localhost', 27017) #Cliente mongo para conexion a repositorio de tiles y chips
db = clientMongo.deepAlerts

try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
clientPlanet = api.ClientV1()

# %%
result = requests.get('https://api.planet.com/basemaps/v1/mosaics', auth=HTTPBasicAuth(os.environ['PL_API_KEY_IDEAM'], ''))
result = json.loads(result.text)

# %%
result
# Out:
# {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#  'mosaics': [{'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/48fff803-4104-49bc-b913-7467b7a5ffb5?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_01_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-179, -56, 180, 58],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2016-01-01T00:00:00.000Z',
#    'grid': {'quad_size': 2048, 'resolution': 4.777314267823516},
#    'id': '48fff803-4104-49bc-b913-7467b7a5ffb5',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2016-02-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2016_01_mosaic',
#    'product_type': 'timelapse'},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/f2952136-69bc-4c31-bc21-a2e3919042a1?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_12_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-180, -56, 180, 62],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2016-12-01T00:00:00.000Z',
#    'grid': {'quad_size': 2048, 'resolution': 4.777314267823516},
#    'id': 'f2952136-69bc-4c31-bc21-a2e3919042a1',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2017-01-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2016_12_mosaic',
#    'product_type': 'timelapse'},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/5b9d2f32-7329-419a-9822-5d4cdfefe198?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2017_01_mutate_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-180, -56, 180, 67],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2017-01-01T00:00:00.000Z',
#    'grid': {'quad_size': 2048, 'resolution': 4.777314267823516},
#    'id': '5b9d2f32-7329-419a-9822-5d4cdfefe198',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2017-02-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2017_01_mutate_mosaic',
#    'product_type': 'timelapse'},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/889874a4-c9fb-49b4-b696-fa1cc92f1808?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2017_12_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-180, -57, 180, 62],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2017-12-01T00:00:00.000Z',
#    'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#    'id': '889874a4-c9fb-49b4-b696-fa1cc92f1808',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2018-01-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2017_12_mosaic',
#    'product_type': 'timelapse'},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/48bd68d0-011d-4d00-92f5-ffce9432cda8?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2018_01_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-180, -57, 180, 68],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2018-01-01T00:00:00.000Z',
#    'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#    'id': '48bd68d0-011d-4d00-92f5-ffce9432cda8',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2018-02-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2018_01_mosaic',
#    'product_type': 'timelapse'},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/f876dcf1-e4ad-4624-85b0-e5a222caadf0?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'quads': 'https://api.planet.com/basemaps/v1/mosaics/f876dcf1-e4ad-4624-85b0-e5a222caadf0/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2018_11_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-180, -56.36525, 180, 66.722541],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2018-11-01T00:00:00.000Z',
#    'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#    'id': 'f876dcf1-e4ad-4624-85b0-e5a222caadf0',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2018-12-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2018_11_mosaic',
#    'product_type': 'timelapse',
#    'quad_download': True},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/d9264bbc-a677-4828-8493-467558cb348d?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'quads': 'https://api.planet.com/basemaps/v1/mosaics/d9264bbc-a677-4828-8493-467558cb348d/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2018_12_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-180, -56.170023, 180, 57.984808],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2018-12-01T00:00:00.000Z',
#    'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#    'id': 'd9264bbc-a677-4828-8493-467558cb348d',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2019-01-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2018_12_mosaic',
#    'product_type': 'timelapse',
#    'quad_download': True},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/b9a1ee8a-190c-45cd-bb1a-fe136db118f2?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'quads': 'https://api.planet.com/basemaps/v1/mosaics/b9a1ee8a-190c-45cd-bb1a-fe136db118f2/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_01_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-180, -56.072035, 180, 61.438767],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2019-01-01T00:00:00.000Z',
#    'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#    'id': 'b9a1ee8a-190c-45cd-bb1a-fe136db118f2',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2019-02-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2019_01_mosaic',
#    'product_type': 'timelapse',
#    'quad_download': True},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/14154e5d-0ff0-48af-8ee7-5303f80e98a4?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'quads': 'https://api.planet.com/basemaps/v1/mosaics/14154e5d-0ff0-48af-8ee7-5303f80e98a4/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_02_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-180, -56.656226, 180, 72.235514],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2019-02-01T00:00:00.000Z',
#    'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#    'id': '14154e5d-0ff0-48af-8ee7-5303f80e98a4',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2019-03-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2019_02_mosaic',
#    'product_type': 'timelapse',
#    'quad_download': True},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/af953970-7189-473a-8e26-24397577eaa2?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'quads': 'https://api.planet.com/basemaps/v1/mosaics/af953970-7189-473a-8e26-24397577eaa2/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_03_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-179.999999974944,
#     -56.072035466496,
#     179.999999975056,
#     76.016093660188],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2019-03-01T00:00:00.000Z',
#    'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#    'id': 'af953970-7189-473a-8e26-24397577eaa2',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2019-04-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2019_03_mosaic',
#    'product_type': 'timelapse',
#    'quad_download': True},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/2cb5dc96-7de0-4cbd-a92c-751269440b59?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'quads': 'https://api.planet.com/basemaps/v1/mosaics/2cb5dc96-7de0-4cbd-a92c-751269440b59/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_04_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-179.999999974944,
#     -56.365250131551,
#     179.999999975056,
#     76.016093660188],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2019-04-01T00:00:00.000Z',
#    'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#    'id': '2cb5dc96-7de0-4cbd-a92c-751269440b59',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2019-05-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2019_04_mosaic',
#    'product_type': 'timelapse',
#    'quad_download': True},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/3ad57d23-4da1-4d4e-956d-f66015ef4d10?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'quads': 'https://api.planet.com/basemaps/v1/mosaics/3ad57d23-4da1-4d4e-956d-f66015ef4d10/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_05_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-179.999999974944,
#     -56.365250131551,
#     179.999999975056,
#     76.016093660188],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2019-05-01T00:00:00.000Z',
#    'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#    'id': '3ad57d23-4da1-4d4e-956d-f66015ef4d10',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2019-06-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2019_05_mosaic',
#    'product_type': 'timelapse',
#    'quad_download': True},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/e6fe5d09-891f-44c6-a74c-c2de1f43383c?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'quads': 'https://api.planet.com/basemaps/v1/mosaics/e6fe5d09-891f-44c6-a74c-c2de1f43383c/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_06_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-179.999999974944,
#     -55.875310830392,
#     179.999999975056,
#     76.016093660188],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2019-06-01T00:00:00.000Z',
#    'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#    'id': 'e6fe5d09-891f-44c6-a74c-c2de1f43383c',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2019-07-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2019_06_mosaic',
#    'product_type': 'timelapse',
#    'quad_download': True},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/713db44d-fe75-4ba5-aa6d-defbd8c890cf?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#     'quads': 'https://api.planet.com/basemaps/v1/mosaics/713db44d-fe75-4ba5-aa6d-defbd8c890cf/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#     'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_07_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#    'bbox': [-179.999999974944,
#     -56.072035466496,
#     179.999999975056,
#     76.016093660188],
#    'coordinate_system': 'EPSG:3857',
#    'datatype': 'byte',
#    'first_acquired': '2019-07-01T00:00:00.000Z',
#    'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#    'id': '713db44d-fe75-4ba5-aa6d-defbd8c890cf',
#    'interval': '1 mon',
#    'item_types': ['PSScene3Band', 'REOrthoTile'],
#    'last_acquired': '2019-08-01T00:00:00.000Z',
#    'level': 15,
#    'name': 'global_monthly_2019_07_mosaic',
#    'product_type': 'timelapse',
#    'quad_download': True}]}

# %%
x=list(filter(lambda person: '201' in person['name'], result['mosaics']))
x
# Out:
# [{'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/48fff803-4104-49bc-b913-7467b7a5ffb5?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_01_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-179, -56, 180, 58],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2016-01-01T00:00:00.000Z',
#   'grid': {'quad_size': 2048, 'resolution': 4.777314267823516},
#   'id': '48fff803-4104-49bc-b913-7467b7a5ffb5',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2016-02-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2016_01_mosaic',
#   'product_type': 'timelapse'},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/f2952136-69bc-4c31-bc21-a2e3919042a1?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_12_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-180, -56, 180, 62],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2016-12-01T00:00:00.000Z',
#   'grid': {'quad_size': 2048, 'resolution': 4.777314267823516},
#   'id': 'f2952136-69bc-4c31-bc21-a2e3919042a1',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2017-01-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2016_12_mosaic',
#   'product_type': 'timelapse'},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/5b9d2f32-7329-419a-9822-5d4cdfefe198?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2017_01_mutate_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-180, -56, 180, 67],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2017-01-01T00:00:00.000Z',
#   'grid': {'quad_size': 2048, 'resolution': 4.777314267823516},
#   'id': '5b9d2f32-7329-419a-9822-5d4cdfefe198',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2017-02-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2017_01_mutate_mosaic',
#   'product_type': 'timelapse'},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/889874a4-c9fb-49b4-b696-fa1cc92f1808?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2017_12_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-180, -57, 180, 62],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2017-12-01T00:00:00.000Z',
#   'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#   'id': '889874a4-c9fb-49b4-b696-fa1cc92f1808',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2018-01-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2017_12_mosaic',
#   'product_type': 'timelapse'},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/48bd68d0-011d-4d00-92f5-ffce9432cda8?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2018_01_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-180, -57, 180, 68],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2018-01-01T00:00:00.000Z',
#   'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#   'id': '48bd68d0-011d-4d00-92f5-ffce9432cda8',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2018-02-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2018_01_mosaic',
#   'product_type': 'timelapse'},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/f876dcf1-e4ad-4624-85b0-e5a222caadf0?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'quads': 'https://api.planet.com/basemaps/v1/mosaics/f876dcf1-e4ad-4624-85b0-e5a222caadf0/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2018_11_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-180, -56.36525, 180, 66.722541],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2018-11-01T00:00:00.000Z',
#   'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#   'id': 'f876dcf1-e4ad-4624-85b0-e5a222caadf0',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2018-12-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2018_11_mosaic',
#   'product_type': 'timelapse',
#   'quad_download': True},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/d9264bbc-a677-4828-8493-467558cb348d?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'quads': 'https://api.planet.com/basemaps/v1/mosaics/d9264bbc-a677-4828-8493-467558cb348d/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2018_12_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-180, -56.170023, 180, 57.984808],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2018-12-01T00:00:00.000Z',
#   'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#   'id': 'd9264bbc-a677-4828-8493-467558cb348d',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2019-01-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2018_12_mosaic',
#   'product_type': 'timelapse',
#   'quad_download': True},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/b9a1ee8a-190c-45cd-bb1a-fe136db118f2?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'quads': 'https://api.planet.com/basemaps/v1/mosaics/b9a1ee8a-190c-45cd-bb1a-fe136db118f2/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_01_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-180, -56.072035, 180, 61.438767],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2019-01-01T00:00:00.000Z',
#   'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#   'id': 'b9a1ee8a-190c-45cd-bb1a-fe136db118f2',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2019-02-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2019_01_mosaic',
#   'product_type': 'timelapse',
#   'quad_download': True},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/14154e5d-0ff0-48af-8ee7-5303f80e98a4?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'quads': 'https://api.planet.com/basemaps/v1/mosaics/14154e5d-0ff0-48af-8ee7-5303f80e98a4/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_02_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-180, -56.656226, 180, 72.235514],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2019-02-01T00:00:00.000Z',
#   'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#   'id': '14154e5d-0ff0-48af-8ee7-5303f80e98a4',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2019-03-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2019_02_mosaic',
#   'product_type': 'timelapse',
#   'quad_download': True},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/af953970-7189-473a-8e26-24397577eaa2?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'quads': 'https://api.planet.com/basemaps/v1/mosaics/af953970-7189-473a-8e26-24397577eaa2/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_03_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-179.999999974944,
#    -56.072035466496,
#    179.999999975056,
#    76.016093660188],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2019-03-01T00:00:00.000Z',
#   'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#   'id': 'af953970-7189-473a-8e26-24397577eaa2',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2019-04-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2019_03_mosaic',
#   'product_type': 'timelapse',
#   'quad_download': True},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/2cb5dc96-7de0-4cbd-a92c-751269440b59?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'quads': 'https://api.planet.com/basemaps/v1/mosaics/2cb5dc96-7de0-4cbd-a92c-751269440b59/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_04_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-179.999999974944,
#    -56.365250131551,
#    179.999999975056,
#    76.016093660188],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2019-04-01T00:00:00.000Z',
#   'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#   'id': '2cb5dc96-7de0-4cbd-a92c-751269440b59',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2019-05-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2019_04_mosaic',
#   'product_type': 'timelapse',
#   'quad_download': True},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/3ad57d23-4da1-4d4e-956d-f66015ef4d10?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'quads': 'https://api.planet.com/basemaps/v1/mosaics/3ad57d23-4da1-4d4e-956d-f66015ef4d10/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_05_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-179.999999974944,
#    -56.365250131551,
#    179.999999975056,
#    76.016093660188],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2019-05-01T00:00:00.000Z',
#   'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#   'id': '3ad57d23-4da1-4d4e-956d-f66015ef4d10',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2019-06-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2019_05_mosaic',
#   'product_type': 'timelapse',
#   'quad_download': True},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/e6fe5d09-891f-44c6-a74c-c2de1f43383c?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'quads': 'https://api.planet.com/basemaps/v1/mosaics/e6fe5d09-891f-44c6-a74c-c2de1f43383c/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_06_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-179.999999974944,
#    -55.875310830392,
#    179.999999975056,
#    76.016093660188],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2019-06-01T00:00:00.000Z',
#   'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#   'id': 'e6fe5d09-891f-44c6-a74c-c2de1f43383c',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2019-07-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2019_06_mosaic',
#   'product_type': 'timelapse',
#   'quad_download': True},
#  {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/713db44d-fe75-4ba5-aa6d-defbd8c890cf?api_key=5a78a5a455644480a8a40ce5b4af9caa',
#    'quads': 'https://api.planet.com/basemaps/v1/mosaics/713db44d-fe75-4ba5-aa6d-defbd8c890cf/quads?api_key=5a78a5a455644480a8a40ce5b4af9caa&bbox={lx},{ly},{ux},{uy}',
#    'tiles': 'https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_07_mosaic/gmap/{z}/{x}/{y}.png?api_key=5a78a5a455644480a8a40ce5b4af9caa'},
#   'bbox': [-179.999999974944,
#    -56.072035466496,
#    179.999999975056,
#    76.016093660188],
#   'coordinate_system': 'EPSG:3857',
#   'datatype': 'byte',
#   'first_acquired': '2019-07-01T00:00:00.000Z',
#   'grid': {'quad_size': 4096, 'resolution': 4.777314267823516},
#   'id': '713db44d-fe75-4ba5-aa6d-defbd8c890cf',
#   'interval': '1 mon',
#   'item_types': ['PSScene3Band', 'REOrthoTile'],
#   'last_acquired': '2019-08-01T00:00:00.000Z',
#   'level': 15,
#   'name': 'global_monthly_2019_07_mosaic',
#   'product_type': 'timelapse',
#   'quad_download': True}]

# %%
for mosaic in result["mosaics"]:
    mosaics = db.mosaics
    mosaic_id = mosaics.insert_one(mosaic).inserted_id #Escribir en repositorio el link al nuevo tileresult

# %%
#load deforestation Points

def loadDefPoints(pointPath):#Falta especificar fecha o arvhivo en los argumentos.
    gdf=gpd.GeoDataFrame.from_file()
    gdf["x"] = gdf.centroid.y
    gdf["y"] = gdf.centroid.x
    df=gdf[["x","y"]]
    return df

# %%
#Se calculan las cuatro esquinas del chip para el punto i
def chipVertices(p,delta,pixeles):
    delta_grados=delta*pixeles/2
    chipVertices=[]
    chipVertices.append((df["x"][i]+delta_grados,df["y"][i]+delta_grados))
    chipVertices.append((df["x"][i]-delta_grados,df["y"][i]-delta_grados))
    chipVertices.append((df["x"][i]+delta_grados,df["y"][i]-delta_grados))
    chipVertices.append((df["x"][i]-delta_grados,df["y"][i]+delta_grados))
    return chipVertices

# %%
#Codigo para optener el tile correspondiente a una coordenada. 
#Se identifica el tile para cada esquina.
def chipTiles(p,delta,pixeles,z):
    chipV=chipVertices(p,delta,pixeles)
    tiles=[]
    for p in chipV:
        latitude, longitude, zoom = p[0],p[1], z
        tile = Tile.for_latitude_longitude(latitude, longitude, zoom)
        tiles.append(tile.google)
    tiles = np.unique(tiles, axis=0) 
    zz = [] 
    for i in tiles:
       zz.append(tuple(i))
    tiles=zz
    return tiles

# %%
#Peticion de til 1024x1024 metros til segu sistema z,x,y para el mosaico disponible
def getTile(mosaicName,x,y,z,dirName, fileName):
    try:
        
        result = requests.get('https://tiles.planet.com/basemaps/v1/planet-tiles/%s/gmap/%s/%s/%s.png'%(mosaicName,str(z),x,y),
                              auth=HTTPBasicAuth('5a78a5a455644480a8a40ce5b4af9caa',''))#os.environ['PL_API_KEY_IDEAM'],''))
        with open(dirName+'/'+fileName, 'wb') as f: 
            f.write(result.content) #Guardar imagen en archivo
            google_x, google_y, zoom = x, y, 15
            tile = Tile.from_google(google_x, google_y, zoom)
            post = {"dir_name":dirName,
                    "file_name":fileName,
                    "mosaic_name": mosaicName,
                    "x": str(x),
                    "y": str(y),
                    "z": str(z),
                    "bounds": tile.bounds}
            tiles = db.tiles
            tiles_id = tiles.insert_one(post).inserted_id #Escribir en repositorio el link al nuevo tile
        return "ok"
    except:
        return "error"
        
def getTiles(tiles,mosaicName,z,dirName):
    b=0
    c=0
    d=0
    for tile in tiles:
        fileName='%s_%s_%s_%s.png'%(mosaicName,z,tile[0],tile[1])
        #COnsultar si tile existe en BD; si si pasa si no descarga
        tiles = db.tiles
        q=tiles.find({"dir_name": dirName,"file_name": fileName}).count()
        if q == 0:
            a=getTile(mosaicName,tile[0],tile[1],z,dirName, fileName) 
            if a=="ok":
                b=b+1
            else:
                c=c+1
        else:
            
            pass
        d=d+1
        #x= d%(round(tiles.count_documents()/10,0))
        #if x == 0:
              #print(x*100,'%')
    return (c,b)

# %%
df=loadDefPoints('finalx.geojson')
a=0
b=df.shape[0]-1
df1=df[a:b] #Partir el dataset para poder paralelizar la funcion.
df1=df1.reset_index()
dirName="global_monthly_2019_01_mosaic"

#Worker1 Descargar Tiles si ya no estan en BD y crear chips para cada punto para su subdataset asignado.

a1=0
b1=0
for i in range(df1.shape[0]):
    delta=0.0000429153086046707 #grados por pixel en tile planet xyz @z=15
    pixeles=256
    z=15
    p=(df["x"][i],df["y"][i])
    mosaicName="global_monthly_2019_01_mosaic" #Aqui esete nombre depende de la fecha de descarga
    tiles=chipTiles(p,delta,pixeles,z)
    g=getTiles(tiles,mosaicName,z,dirName)
    a1=a1+g[1]
    b1=b1+g[0]
    if i%100==0:
        print('Download at: ',(100*i)/df1.shape[0],'% ', a1, "tiles downloades of ", a1+b1)
        
clientMongo.close()
print(a1, "tiles downloades of ", a1+b1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
# Download at:  0.0 %  0 tiles downloades of  0
# Download at:  2.706359945872801 %  340 tiles downloades of  340
# Download at:  5.412719891745602 %  627 tiles downloades of  627
# Download at:  8.119079837618404 %  827 tiles downloades of  827
# Download at:  10.825439783491204 %  916 tiles downloades of  916
# Download at:  13.531799729364005 %  1008 tiles downloades of  1008
# Download at:  16.23815967523681 %  1092 tiles downloades of  1092
# Download at:  18.944519621109606 %  1345 tiles downloades of  1345
# Download at:  21.650879566982407 %  1566 tiles downloades of  1566
# Download at:  24.35723951285521 %  1749 tiles downloades of  1749
# Download at:  27.06359945872801 %  1922 tiles downloades of  1922
# Download at:  29.76995940460081 %  1978 tiles downloades of  1978
# Download at:  32.47631935047362 %  2046 tiles downloades of  2046
# Download at:  35.182679296346414 %  2178 tiles downloades of  2178
# Download at:  37.88903924221921 %  2291 tiles downloades of  2291
# Download at:  40.59539918809202 %  2480 tiles downloades of  2480
# Download at:  43.301759133964815 %  2643 tiles downloades of  2643
# Download at:  46.00811907983762 %  2850 tiles downloades of  2850
# Download at:  48.71447902571042 %  3078 tiles downloades of  3078
# Download at:  51.42083897158322 %  3235 tiles downloades of  3235
# Download at:  54.12719891745602 %  3413 tiles downloades of  3413
# Download at:  56.833558863328825 %  3739 tiles downloades of  3739
# Download at:  59.53991880920162 %  4040 tiles downloades of  4040
# Download at:  62.24627875507443 %  4276 tiles downloades of  4276
# Download at:  64.95263870094723 %  4593 tiles downloades of  4593
# Download at:  67.65899864682002 %  4852 tiles downloades of  4852
# Download at:  70.36535859269283 %  5118 tiles downloades of  5118
# Download at:  73.07171853856563 %  5308 tiles downloades of  5308
# Download at:  75.77807848443842 %  5480 tiles downloades of  5480
# Download at:  78.48443843031123 %  5782 tiles downloades of  5782
# Download at:  81.19079837618403 %  6063 tiles downloades of  6063
# Download at:  83.89715832205684 %  6328 tiles downloades of  6328
# Download at:  86.60351826792963 %  6594 tiles downloades of  6594
# Download at:  89.30987821380243 %  6928 tiles downloades of  6928
# Download at:  92.01623815967524 %  7242 tiles downloades of  7242
# Download at:  94.72259810554804 %  7501 tiles downloades of  7501
# Download at:  97.42895805142084 %  7665 tiles downloades of  7665
# 7925 tiles downloades of  7925
